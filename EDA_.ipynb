# %%
import numpy as np

import pandas as pd

import matplotlib.pyplot as plt




# !pip install matplotlib

# %%
df = pd.read_csv(r"C:\\Users\\KOIN\\Downloads\\tips.csv")

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
sns.countplot( x = df["smoker"])
# Out:
# <Axes: xlabel='smoker', ylabel='count'>

# %%
df["smoker"].value_counts()
# Out:
# smoker
# No     151
# Yes     93
# Name: count, dtype: int64

# %%
df["day"].value_counts()
# Out:
# day
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: count, dtype: int64

# %%
df["sex"].value_counts()
# Out:
# sex
# Male      157
# Female     87
# Name: count, dtype: int64

# %%
df["day"].value_counts().plot(kind = "bar")
# Out:
# <Axes: xlabel='day'>

# %%
df["day"].value_counts().plot(kind = "barh")
# Out:
# <Axes: ylabel='day'>

# %%
df["day"].value_counts().plot(kind = "line")
# Out:
# <Axes: xlabel='day'>

# %%
sns.countplot( x = df["day"])
# Out:
# <Axes: xlabel='day', ylabel='count'>

# %%
df["smoker"].value_counts().plot(kind = "pie" , autopct = "%.1f")
# Out:
# <Axes: ylabel='count'>

# %%
sns.distplot(df["total_bill"])
# Out:
# C:\Users\KOIN\AppData\Local\Temp\ipykernel_7304\2943580123.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["total_bill"])
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
sns.distplot(df["total_bill"] , hist= False)
# Out:
# C:\Users\KOIN\AppData\Local\Temp\ipykernel_10292\3200192040.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["total_bill"] , hist= False)
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
sns.boxplot(df["size"])
# Out:
# <Axes: ylabel='size'>

# %%
sns.scatterplot( x = df["total_bill"],
                 y = df["tip"])
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(data = df , x = "total_bill" , y = "tip" , hue = "day" )
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot( x = "total_bill" , y = "tip" , data = df , hue = df["sex"] , style = df["smoker"])
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.barplot( x= df["tip"] , y = df["day"])
# Out:
# <Axes: xlabel='tip', ylabel='day'>

# %%
sns.barplot( data = df , x= "total_bill" , y= "time" , hue = "sex")
# Out:
# <Axes: xlabel='total_bill', ylabel='time'>

# %%
a = pd.crosstab(df["smoker"] , df["day"])

# %%
a
# Out:
# day     Fri  Sat  Sun  Thur
# smoker
# No        4   45   57    45
# Yes      15   42   19    17

# %%
sns.heatmap(a)
# Out:
# <Axes: xlabel='day', ylabel='smoker'>

# %%
sns.pairplot(df)

# %%
import pandas as pd
from pandas_profiling import ProfileReport

# Load the Titanic dataset using a raw string literal
file_path = r"C:\Users\KOIN\Downloads\titanic.csv"
tdf = pd.read_csv(file_path)
tdf.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
print(tdf.describe())

print(tdf['Sex'].value_counts())
print(tdf['Embarked'].value_counts())
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   418.000000  418.000000  418.000000  332.000000  418.000000
# mean   1100.500000    0.363636    2.265550   30.272590    0.447368
# std     120.810458    0.481622    0.841838   14.181209    0.896760
# min     892.000000    0.000000    1.000000    0.170000    0.000000
# 25%     996.250000    0.000000    1.000000   21.000000    0.000000
# 50%    1100.500000    0.000000    3.000000   27.000000    0.000000
# 75%    1204.750000    1.000000    3.000000   39.000000    1.000000
# max    1309.000000    1.000000    3.000000   76.000000    8.000000
#
#             Parch        Fare
# count  418.000000  417.000000
# mean     0.392344   35.627188
# std      0.981429   55.907576
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   14.454200
# 75%      0.000000   31.500000
# max      9.000000  512.329200
# Sex
# male      266
# female    152
# Name: count, dtype: int64
# Embarked
# ...

# %%
# correlation_matrix = tdf.corr()
# print(correlation_matrix)

# %%
import seaborn as sns

import matplotlib.pyplot as plt

# %%
sns.heatmap(correlation_matrix , annot=True  ,cmap="coolwarm")

plt.title("correlation_matrix")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 sns.heatmap(correlation_matrix , annot=True  ,cmap="coolwarm")
#       3 plt.title("correlation_matrix")
#       4 plt.show()
#
# NameError: name 'correlation_matrix' is not defined

# %%
tdf['Age'].plot(kind='hist', bins=25, figsize=(10, 9))
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Distribution of Age')
plt.show()

# %%
tdf['Survived'].value_counts().plot(kind='bar', figsize=(8, 6))
plt.xlabel('Survived')
plt.ylabel('Count')
plt.title('Survival Count')
plt.show()

# %%
print(tdf.isnull().sum())

# Visualize missing values using heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(tdf.isnull(), cmap='viridis')
plt.title('Missing Values')
plt.show()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
print(tdf.nunique())
# Out:
# PassengerId    418
# Survived         2
# Pclass           3
# Name           418
# Sex              2
# Age             79
# SibSp            7
# Parch            8
# Ticket         363
# Fare           169
# Cabin           76
# Embarked         3
# dtype: int64

# %%
sns.pairplot(tdf[['Age', 'Fare', 'Survived']], hue='Survived', height=4)
plt.show()

# %%
pd.crosstab(tdf['Sex'], tdf['Survived']).plot(kind='bar', stacked=True)
plt.xlabel('Sex')
plt.ylabel('Count')
plt.title('Survival by Sex')
plt.show()

# %%
print(tdf.dtypes)
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
constant_columns = [col for col in tdf.columns if tdf[col].nunique() == 1]
print("Constant columns:", constant_columns)
# Out:
# Constant columns: []

# %%
profile = ProfileReport(tdf)
profile.to_file("tdf1_report.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
