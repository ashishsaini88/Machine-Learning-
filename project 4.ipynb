# %%
pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.1 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.1 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.1 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.1 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.1 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.1 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.1 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/8.1 MB 183.5 kB/s eta 0:00:42
#    -- ------------------------------------- 0.5/8.1 MB 183.5 kB/s eta 0:00:42
#    -- ------------------------------------- 0.5/8.1 MB 183.5 kB/s eta 0:00:42
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd 
import numpy as np

# %%
path = r"C:\Users\KOIN\Downloads\placement.csv"
da = pd.read_csv(path)
da
# Out:
#      cgpa  package
# 0    6.89     3.26
# 1    5.12     1.98
# 2    7.82     3.25
# 3    7.42     3.67
# 4    6.94     3.57
# ..    ...      ...
# 195  6.93     2.46
# 196  5.89     2.57
# 197  7.21     3.24
# 198  7.63     3.96
# 199  6.22     2.33
#
# [200 rows x 2 columns]

# %%
da.isnull().sum()

da.fillna(da.mean(numeric_only=True) , inplace=True)

# %%
plt.scatter(da["cgpa"] , da["package"])
plt.xlabel("CGPA")
plt.ylabel("Packege(in LPA)")
# Out:
# Text(0, 0.5, 'Packege(in LPA)')

# %%
x= da.iloc[:,0:1]

y= da.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split

x_train ,x_test ,  y_train ,y_test = train_test_split(x,y, test_size=0.3 , random_state=45)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()
lr.fit(x_train , y_train)
# Out:
# LinearRegression()

# %%
x_test
# Out:
#      cgpa
# 45   7.87
# 72   7.78
# 40   9.38
# 58   6.92
# 25   7.28
# 13   6.93
# 153  7.94
# 80   7.63
# 3    7.42
# 44   5.09
# 134  7.20
# 149  8.28
# 173  6.75
# 33   6.35
# 62   6.34
# 182  5.88
# 112  8.58
# 129  7.29
# 69   7.30
# 190  6.19
# 133  6.05
# 172  6.93
# 35   6.87
# 157  6.47
# 187  6.26
# 10   5.32
# 104  7.62
# 177  7.09
# 26   8.31
# 171  8.01
# 147  5.66
# 0    6.89
# 109  7.77
# 194  7.89
# 151  6.12
# 82   5.58
# 64   7.36
# 169  9.31
# 4    6.94
# 28   5.94
# 97   5.98
# 174  7.32
# 138  7.91
# 67   6.51
# 175  7.04
# 116  9.04
# 135  6.10
# 29   7.15
# 61   5.48
# 83   8.44
# 183  7.28
# 184  7.88
# 176  6.29
# 167  8.13
# 38   8.62
# 79   7.18
# 186  7.84
# 188  7.35
# 84   4.26
# 168  8.65

# %%
lr.predict(x_test.iloc[0].values.reshape(1,1))
# Out:
# C:\Users\KOIN\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([3.49184256])

# %%
x_test
# Out:
#      cgpa
# 45   7.87
# 72   7.78
# 40   9.38
# 58   6.92
# 25   7.28
# 13   6.93
# 153  7.94
# 80   7.63
# 3    7.42
# 44   5.09
# 134  7.20
# 149  8.28
# 173  6.75
# 33   6.35
# 62   6.34
# 182  5.88
# 112  8.58
# 129  7.29
# 69   7.30
# 190  6.19
# 133  6.05
# 172  6.93
# 35   6.87
# 157  6.47
# 187  6.26
# 10   5.32
# 104  7.62
# 177  7.09
# 26   8.31
# 171  8.01
# 147  5.66
# 0    6.89
# 109  7.77
# 194  7.89
# 151  6.12
# 82   5.58
# 64   7.36
# 169  9.31
# 4    6.94
# 28   5.94
# 97   5.98
# 174  7.32
# 138  7.91
# 67   6.51
# 175  7.04
# 116  9.04
# 135  6.10
# 29   7.15
# 61   5.48
# 83   8.44
# 183  7.28
# 184  7.88
# 176  6.29
# 167  8.13
# 38   8.62
# 79   7.18
# 186  7.84
# 188  7.35
# 84   4.26
# 168  8.65

# %%
plt.scatter(da["cgpa"] , da["package"])
plt.plot(x_train, lr.predict(x_train) , color="red")
plt.xlabel("CGPA")
plt.ylabel("Package(in LPA )")
# Out:
# Text(0, 0.5, 'Package(in LPA )')

# %%
m=lr.intercept_
m
# Out:
# np.float64(-1.0338557486271283)

# %%
b=lr.coef_
b
# Out:
# array([0.57505696])

# %%
m * 6.22 + b
# Out:
# array([-5.85552579])

# %%
m*8+b
# Out:
# array([-7.69578902])

# %%
class mylr:

    def __init__(self):
         self.m = None
         self.b = None

    def fit(self,x_train,y_train):

         num =0
         den =0


         for i in range (x_train.shape[0]):

             num = num + ((x_train[i] - x_train.mean()) * (y_train[i] - y_train.mean()))

             den = den + ((x_train[i] - x_train.mean()) * (y_train[i] - y_train.mean()))


            self.m = num / den 
            self.b = y_train.mean() - (self.m* x_train.mean())
            print(self.m)
            print(self.b)


   def predict(self,x_test):

       print(x_test)


       return self.m* x_test + self.b
# Out:
#   File <string>:20
#     self.m = num / den
#                        ^
# IndentationError: unindent does not match any outer indentation level

# %%
class mylr: #mera constructor
    
    def __init__(self): # initializing 2 things
        self.m = None
        self.b = None
        
    def fit(self,X_train,y_train):  #kyunki ye ek machine learning algorithm h, isme 2 methods toh hone hi chaiye
        
        num = 0
        den = 0
        
        for i in range(X_train.shape[0]):
            
            num = num + ((X_train[i] - X_train.mean())*(y_train[i] - y_train.mean()))
            den = den + ((X_train[i] - X_train.mean())*(X_train[i] - X_train.mean()))
        
        self.m = num/den
        self.b = y_train.mean() - (self.m * X_train.mean())
        print(self.m)
        print(self.b)       
    
    def predict(self,X_test):
        
        print(X_test)
        
        return self.m * X_test + self.b

# %%
df = pd.read_csv(path)
df
# Out:
#      cgpa  package
# 0    6.89     3.26
# 1    5.12     1.98
# 2    7.82     3.25
# 3    7.42     3.67
# 4    6.94     3.57
# ..    ...      ...
# 195  6.93     2.46
# 196  5.89     2.57
# 197  7.21     3.24
# 198  7.63     3.96
# 199  6.22     2.33
#
# [200 rows x 2 columns]

# %%
x= df.iloc[:,0].values
y= df.iloc[:,1].values

# %%
x_train ,x_test , y_train , y_test = train_test_split (x,y , test_size=0.3 , random_state=45)

# %%
x_test.shape
# Out:
# (60,)

# %%
lr = mylr()

# %%
lr.fit(x_train ,y_train)
# Out:
# 0.5750569647609316
# -1.0338557486271283

# %%
x_train[0]
# Out:
# np.float64(6.85)

# %%
lr.predict(x_test[0])
# Out:
# 7.87
# np.float64(3.491842564041404)

# %%
df
# Out:
#      cgpa  package
# 0    6.89     3.26
# 1    5.12     1.98
# 2    7.82     3.25
# 3    7.42     3.67
# 4    6.94     3.57
# ..    ...      ...
# 195  6.93     2.46
# 196  5.89     2.57
# 197  7.21     3.24
# 198  7.63     3.96
# 199  6.22     2.33
#
# [200 rows x 2 columns]
