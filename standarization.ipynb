# %%
import numpy as np 

from sklearn.preprocessing import StandardScaler

data = np.array([[150,50] ,[160,70] ,[130,40] ,[120,20] ,[180,80]])

standard_scaler = StandardScaler()
data_standard_scaled = standard_scaler.fit_transform(data)


print("data after standerdzation")

print(data_standard_scaled)
# Out:
# data after standerdzation
# [[ 0.09365858 -0.09365858]
#  [ 0.56195149  0.84292723]
#  [-0.84292723 -0.56195149]
#  [-1.31122014 -1.4985373 ]
#  [ 1.4985373   1.31122014]]

# %%
data
# Out:
# array([[150,  50],
#        [160,  70],
#        [130,  40],
#        [120,  20],
#        [180,  80]])

# %%
import pandas as pd 

df = np.array([
       [150,  50],
       [160,  70],
       [130,  40],
       [120,  20],
       [180,  80]])

# %%
df1 = pd.DataFrame(df)

df1
# Out:
#      0   1
# 0  150  50
# 1  160  70
# 2  130  40
# 3  120  20
# 4  180  80

# %%
scaler = StandardScaler()
standardized_data = scaler.fit_transform(df1)

# %%
standardized_data
# Out:
# array([[ 0.09365858, -0.09365858],
#        [ 0.56195149,  0.84292723],
#        [-0.84292723, -0.56195149],
#        [-1.31122014, -1.4985373 ],
#        [ 1.4985373 ,  1.31122014]])

# %%
import pandas as pd 

from sklearn.model_selection import train_test_split

from sklearn.preprocessing import StandardScaler ,LabelEncoder

file_path = r"C://Users//KOIN//Downloads//covid_toy.csv"

data = pd.read_csv(file_path)

# %%
data.head(10)
# Out:
#    age  gender  fever   cough       city has_covid
# 0   60    Male  103.0    Mild    Kolkata        No
# 1   27    Male  100.0    Mild      Delhi       Yes
# 2   42    Male  101.0    Mild      Delhi        No
# 3   31  Female   98.0    Mild    Kolkata        No
# 4   65  Female  101.0    Mild     Mumbai        No
# 5   84  Female    NaN    Mild  Bangalore       Yes
# 6   14    Male  101.0  Strong  Bangalore        No
# 7   20  Female    NaN  Strong     Mumbai       Yes
# 8   19  Female  100.0  Strong  Bangalore        No
# 9   64  Female  101.0    Mild      Delhi        No

# %%
label_encoder = LabelEncoder()

data["cough"] = label_encoder.fit_transform(data["cough"])

data
# Out:
#     age  gender  fever  cough       city has_covid
# 0    60    Male  103.0      0    Kolkata        No
# 1    27    Male  100.0      0      Delhi       Yes
# 2    42    Male  101.0      0      Delhi        No
# 3    31  Female   98.0      0    Kolkata        No
# 4    65  Female  101.0      0     Mumbai        No
# ..  ...     ...    ...    ...        ...       ...
# 95   12  Female  104.0      0  Bangalore        No
# 96   51  Female  101.0      1    Kolkata       Yes
# 97   20  Female  101.0      0  Bangalore        No
# 98    5  Female   98.0      1     Mumbai        No
# 99   10  Female   98.0      1    Kolkata       Yes
#
# [100 rows x 6 columns]

# %%
features = ["age" , "gender"]

X= data[features]

X
# Out:
#     age  gender
# 0    60    Male
# 1    27    Male
# 2    42    Male
# 3    31  Female
# 4    65  Female
# ..  ...     ...
# 95   12  Female
# 96   51  Female
# 97   20  Female
# 98    5  Female
# 99   10  Female
#
# [100 rows x 2 columns]

# %%
target = ["fever" ]

Y = data[target]

Y
# Out:
#     fever
# 0   103.0
# 1   100.0
# 2   101.0
# 3    98.0
# 4   101.0
# ..    ...
# 95  104.0
# 96  101.0
# 97  101.0
# 98   98.0
# 99   98.0
#
# [100 rows x 1 columns]

# %%
featurs = ["age", "gender", "city"]
target = "cough"

X = data[featurs]
Y = data[target]

X.head()
Y
# Out:
# 0     0
# 1     0
# 2     0
# 3     0
# 4     0
#      ..
# 95    0
# 96    1
# 97    0
# 98    1
# 99    1
# Name: cough, Length: 100, dtype: int64

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y , test_size = 0.3 , random_state = 40)

# %%
X_train.head()
# Out:
#     age  gender       city
# 20   12    Male  Bangalore
# 32   34  Female      Delhi
# 51   11  Female    Kolkata
# 0    60    Male    Kolkata
# 54   60  Female     Mumbai

# %%
X_test.head()
# Out:
#     age  gender       city
# 79   48  Female    Kolkata
# 75    5    Male    Kolkata
# 63   10    Male  Bangalore
# 15   70    Male    Kolkata
# 38   49  Female      Delhi

# %%
Y_train.head()
# Out:
# 20    1
# 32    1
# 51    1
# 0     0
# 54    0
# Name: cough, dtype: int64

# %%
Y_test.head()
# Out:
# 79    0
# 75    0
# 63    0
# 15    1
# 38    0
# Name: cough, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
# plt.figure(figsize(14,5))

plt.subplot(1,2,2)

plt.scatter(X_train["age"] , X_train["gender"] , c = Y_train , cmap= "viridis" , alpha= 0.5 )

plt.title("before scaler")

plt.xlabel("age")

plt.ylabel("gender")
# Out:
# Text(0, 0.5, 'gender')
